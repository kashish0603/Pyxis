# %% [markdown]
# * The highest percentage of female victims can be found in the 18-20 age group
# * Highest percentage of male victims can be found in higher age groups.
# * Over fifty percent of identified girl victims are aged between 15 and 17
# * forty percent of trafficked boys are under 12 years of age.
# * half of all victims are aged between 19 and 33
# * There is a slight spike in age at 0 and 1 years of age- this is because of the number of children who are born into trafficking.
#
# source: https://www.ctdatacollaborative.org/story/age-victims-children-and-adults

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\VIIT\ML\SIH data\Pyxis\Database\data.csv")
df.head()
# Out:
#               name gender    race  age    phone_no  dob_year  dob_month  \
# 0            nitin      f  indian   45  7819587282      1977          4
# 1           tripti      m  indian   56  6550763390      1966          5
# 2          somdutt      f  indian   53  4138497486      1969         12
# 3  bhagwati prasad      m  indian   95  1098844205      1927          3
# 4          yognder      m  indian   79  2978310353      1943          3
#
#    dob_day     addhar_no                     email  ...  \
# 0        4  479876071146           nitin@gmail.com  ...
# 1        5  307940090670          tripti@gmail.com  ...
# 2        8  306888775786         somdutt@gmail.com  ...
# 3       25  343798185018  bhagwatiprasad@gmail.com  ...
# 4        8  415960603742         yognder@gmail.com  ...
#
#                    img_rgt_thumb                  img_rgt_index  \
# 0  100__M_Right_thumb_finger.BMP  100__M_Right_index_finger.BMP
# ...

# %%
gender = input("enter f for female and m for male")
input_gender = gender
gender_seprated = (df['gender']==gender)
gender_seprated_sep = df.loc[gender_seprated]

choice = int(input("enter 1 for specific age and 0 for age range"))
if(choice ==0):
    age_upper = int(input("age_upperlimit"))
    age_lower = int(input("age_lowerlimit"))
    age_seprated = gender_seprated_sep[gender_seprated_sep['age']>=age_lower]
    age_seprated = age_seprated[age_seprated['age']<=age_upper]
elif(choice==1):
    age_specific = int(input("enter specific age"))
    age_seprated = gender_seprated_sep[gender_seprated_sep['age']==age_specific]]

# %%
age_seprated
# Out:
#              name gender    race  age    phone_no  dob_year  dob_month  \
# 44   yogitatiwari      f  indian   20  7666744486      2002          8
# 148  kuldeepsingh      f  indian   20  2098784316      2002          4
# 462         aarti      f  indian   20  6542120781      2002          6
#
#      dob_day     addhar_no                   email  ...  \
# 44         9  980198281786  yogitatiwari@gmail.com  ...
# 148        6  976727333393  kuldeepsingh@gmail.com  ...
# 462       29  279074114617         aarti@gmail.com  ...
#
#                      img_rgt_thumb                  img_rgt_index  \
# 44   140__F_Right_thumb_finger.BMP  140__F_Right_index_finger.BMP
# 148  234__M_Right_thumb_finger.BMP  234__M_Right_index_finger.BMP
# 462  517__M_Right_thumb_finger.BMP  517__M_Right_index_finger.BMP
#
#                      img_rgt_middle                  img_rgt_ring  \
# 44   140__F_Right_middle_finger.BMP  140__F_Right_ring_finger.BMP
# ...
